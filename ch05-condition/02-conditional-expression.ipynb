# %% [markdown]
# # 조건부 표현식
# - 단순 조건부 표현식
# `참 if 조건 else 거짓`
# - 중첩 조건부 표현식

# %%
print('# conditinal expression')
print('## simple expression')
x = 35
print('x는 60 이상' if x >= 60 else 'x는 60 미만')
print()

print('## nested expression')
print('x는 90 이상' if x >= 90 else 'x는 60 이상' if x >=60 else 'x는 60 미만')
# Out:
# # conditinal expression
# ## simple expression
# x는 60 미만
#
# ## nested expression
# x는 60 미만
